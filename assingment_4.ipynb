# %% [markdown]
# ##Assingment 4

# %% [markdown]
# Q1.What exactly is []?

# %% [markdown]
# answer(1) :- it is a list which contain then null valuse in a list

# %% [markdown]
# 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %% [markdown]
# answer (2):- spam[2] = 'hello'

# %% [markdown]
# Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.
# 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %% [markdown]
# answer(3) :- spma(3) i.e 'd'

# %% [markdown]
# 4. What is the value of spam[-1]?

# %% [markdown]
# answer(4) :- 'd'

# %% [markdown]
# 5. What is the value of spam[:2]?

# %% [markdown]
# answer(5) :- ['a','b']

# %% [markdown]
# Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.
# 6. What is the value of bacon.index(&#39;cat&#39;)?

# %% [markdown]
# answer(6):- 1

# %% [markdown]
# 7. How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# answer(7) :- [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %% [markdown]
# answer(8) :- [3.14, 11, 'cat', True]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?

# %% [markdown]
# answer(9):- for list concatination the operater is '+' and for repliation operator is '*'

# %% [markdown]
# 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# answer(10) :- append add value to the last of the list and the insert can add anywhere in the list

# %% [markdown]
# 11. What are the two methods for removing items from a list?

# %% [markdown]
# answer(11):- the delete statement i.e del and the remove()

# %% [markdown]
# 12. Describe how list values and string values are identical.

# %% [markdown]
# answer(12):- they both can be use in loop ,we can use len for both , they both cna be conatinate and replicate

# %% [markdown]
# 13. What&#39;s the difference between tuples and lists?

# %% [markdown]
# answer(13):-Lists are mutable; they can have values added, removed, or changed. Tuples are immutable; they cannot be changed at all. Also, tuples are written using parentheses,(), while lists use the square brackets,[]

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# answer(14) :- (42,)

# %% [markdown]
# 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %% [markdown]
# answer(15):-  by using tupe() an list funtion respectively

# %% [markdown]
# 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?

# %% [markdown]
# answer(16) :-  they contain the referene to the list values

# %% [markdown]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# answer(17) :- The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list. That is, only copy.deepcopy() will duplicate any lists inside the list.
